# %% [markdown]
# Tænker det her måske skal slettes? Med mindre nogen renskriver den så den rent faktisk laver partial pooling og man så kan bruge det som et eksempel på hvad vi kunne have gjort hvis vi havde haft mere tid :D Men lige nu tror jeg ikke den er rigtig?
#
# \begin{align*}
# LoC_i &\sim \mathrm{GammaPoisson}(\lambda_i,\varphi_i) \\
# \varphi_i &\sim \mathrm{Exp}(?) \\
# \mathrm{log}(\lambda_i) &= \alpha_{\mathrm{LLM}[i]} + \beta_{\mathrm{LLM}[i]} * (CC_{\mathrm{LLM}[i]}-\bar{CC})\\
# \alpha_j &\sim \mathrm{Normal}(\bar{\alpha},\sigma_\alpha) \\
# \beta_j &\sim \mathrm{Normal}(\bar{\beta},\sigma_\beta) \\
#
# \bar{\alpha} &\sim \mathrm{Normal}(?,?) \\
# \bar{\beta} &\sim \mathrm{Normal}(?,?) \\
# \sigma_\alpha &\sim \mathrm{HalfNormal}(?) \\
# \sigma_\gamma &\sim \mathrm{HalfNormal}(?)
# \end{align*}
